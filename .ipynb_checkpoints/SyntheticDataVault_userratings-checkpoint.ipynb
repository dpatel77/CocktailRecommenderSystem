# %%
# !pip install sdv
# !pip show sdv
# Out:
# Name: sdv
# Version: 1.13.1
# Summary: Generate synthetic data for single table, multi table and sequential data
# Home-page:
# Author:
# Author-email: "DataCebo, Inc." <info@sdv.dev>
# License: BSL-1.1
# Location: /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages
# Requires: boto3, botocore, cloudpickle, copulas, ctgan, deepecho, graphviz, numpy, pandas, platformdirs, pyyaml, rdt, sdmetrics, tqdm
# Required-by:

# %%
# dir(sdv)
import sdv
from sdv.tabular import GaussianCopula

print("SDV version:", sdv.__version__)
print("GaussianCopula imported successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # dir(sdv)
#       2 import sdv
# ----> 3 from sdv.tabular import GaussianCopula
#       5 print("SDV version:", sdv.__version__)
#       6 print("GaussianCopula imported successfully")
#
# ModuleNotFoundError: No module named 'sdv.tabular'

# %%
import os

# Uninstall conflicting packages
os.system("pip uninstall -y botocore aiobotocore")

# Install SDV library
os.system("pip install sdv")

# (Optional) Reinstall aiobotocore with compatible versions
os.system("pip install aiobotocore==2.7.0 botocore==1.31.16")

# Import necessary libraries
import numpy as np
import pandas as pd
# from sdv.tabular import GaussianCopula
from sdv.tabular import CopulaGAN
# Out:
# Found existing installation: botocore 1.34.108
# Uninstalling botocore-1.34.108:
#   Successfully uninstalled botocore-1.34.108
# Found existing installation: aiobotocore 2.4.2
# Uninstalling aiobotocore-2.4.2:
#   Successfully uninstalled aiobotocore-2.4.2
# Requirement already satisfied: sdv in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (1.13.1)
# Requirement already satisfied: boto3>=1.28 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (1.34.108)
# Collecting botocore>=1.31 (from sdv)
#   Obtaining dependency information for botocore>=1.31 from https://files.pythonhosted.org/packages/36/0f/25067a183cb68bd02a6e7db397f9f40c7ee351afdf56987ea41b5d26a053/botocore-1.34.108-py3-none-any.whl.metadata
#   Using cached botocore-1.34.108-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (2.2.1)
# Requirement already satisfied: graphviz>=0.13.2 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (0.20.3)
# Requirement already satisfied: tqdm>=4.29 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (4.65.0)
# Requirement already satisfied: copulas>=0.11.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (0.11.0)
# Requirement already satisfied: ctgan>=0.10.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (0.10.1)
# Requirement already satisfied: deepecho>=0.6.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (0.6.0)
# Requirement already satisfied: rdt>=1.12.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (1.12.1)
# Requirement already satisfied: sdmetrics>=0.14.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (0.14.1)
# Requirement already satisfied: platformdirs>=4.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (4.2.2)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (6.0.1)
# Requirement already satisfied: numpy<2,>=1.23.3 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (1.24.3)
# Requirement already satisfied: pandas>=1.5.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sdv) (2.1.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from boto3>=1.28->sdv) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from boto3>=1.28->sdv) (0.10.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from botocore>=1.31->sdv) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from botocore>=1.31->sdv) (1.26.16)
# Requirement already satisfied: plotly>=5.10.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from copulas>=0.11.0->sdv) (5.22.0)
# Requirement already satisfied: scipy>=1.9.2 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from copulas>=0.11.0->sdv) (1.10.1)
# Requirement already satisfied: torch>=2.0.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from ctgan>=0.10.0->sdv) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->sdv) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->sdv) (2024.1)
# Requirement already satisfied: Faker>=17 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from rdt>=1.12.0->sdv) (25.2.0)
# Requirement already satisfied: scikit-learn>=1.1.3 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from rdt>=1.12.0->sdv) (1.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from plotly>=5.10.0->copulas>=0.11.0->sdv) (8.2.2)
# Requirement already satisfied: packaging in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from plotly>=5.10.0->copulas>=0.11.0->sdv) (23.0)
# Requirement already satisfied: six>=1.5 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.31->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.1.3->rdt>=1.12.0->sdv) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.1.3->rdt>=1.12.0->sdv) (2.2.0)
# Requirement already satisfied: filelock in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (4.9.0)
# Requirement already satisfied: sympy in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (1.11.1)
# Requirement already satisfied: networkx in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (3.1)
# Requirement already satisfied: jinja2 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (3.1.2)
# Requirement already satisfied: fsspec in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->ctgan>=0.10.0->sdv) (2023.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->ctgan>=0.10.0->sdv) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from sympy->torch>=2.0.0->ctgan>=0.10.0->sdv) (1.3.0)
# Using cached botocore-1.34.108-py3-none-any.whl (12.2 MB)
# Installing collected packages: botocore
# Successfully installed botocore-1.34.108
# Collecting aiobotocore==2.7.0
#   Obtaining dependency information for aiobotocore==2.7.0 from https://files.pythonhosted.org/packages/d0/bc/6a96a686845c9f5958fac0ecafa6050ed77d0e71553b3cfe69acbaa70191/aiobotocore-2.7.0-py3-none-any.whl.metadata
#   Downloading aiobotocore-2.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting botocore==1.31.16
#   Obtaining dependency information for botocore==1.31.16 from https://files.pythonhosted.org/packages/d5/f7/8f6a279fd5ef2d4dc1962cee5fffaa45c7414e6e61e9886a0a04513ce569/botocore-1.31.16-py3-none-any.whl.metadata
#   Downloading botocore-1.31.16-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.7.4.post0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiobotocore==2.7.0) (3.8.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiobotocore==2.7.0) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiobotocore==2.7.0) (0.7.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from botocore==1.31.16) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from botocore==1.31.16) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from botocore==1.31.16) (1.26.16)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (1.2.0)
# Requirement already satisfied: typing_extensions>=3.7 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore==2.7.0) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.31.16) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.7.4.post0->aiobotocore==2.7.0) (3.4)
# Downloading aiobotocore-2.7.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 1.4 MB/s eta 0:00:0000:01
# Downloading botocore-1.31.16-py3-none-any.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 41.8 MB/s eta 0:00:0000:010:01
# Installing collected packages: botocore, aiobotocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.108
#     Uninstalling botocore-1.34.108:
#       Successfully uninstalled botocore-1.34.108
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2023.3.0 requires aiobotocore~=2.4.2, but you have aiobotocore 2.7.0 which is incompatible.
# s3transfer 0.10.1 requires botocore<2.0a.0,>=1.33.2, but you have botocore 1.31.16 which is incompatible.
# boto3 1.34.108 requires botocore<1.35.0,>=1.34.108, but you have botocore 1.31.16 which is incompatible.
# Successfully installed aiobotocore-2.7.0 botocore-1.31.16
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 16
#      14 import pandas as pd
#      15 # from sdv.tabular import GaussianCopula
# ---> 16 from sdv.tabular import CopulaGAN
#
# ModuleNotFoundError: No module named 'sdv.tabular'

# %%
# Load the CSV File

# %%
import os

# # Uninstall conflicting packages
# os.system("pip uninstall -y botocore aiobotocore")

# # Install SDV library
# os.system("pip install sdv")

# # (Optional) Reinstall aiobotocore with compatible versions
# os.system("pip install aiobotocore==2.7.0 botocore==1.31.16")

# Import necessary libraries
import numpy as np
import pandas as pd
from sdv.tabular import CopulaGAN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 15
#      13 import numpy as np
#      14 import pandas as pd
# ---> 15 from sdv.tabular import CopulaGAN
#
# ModuleNotFoundError: No module named 'sdv.tabular'

# %%
# Load the dataset
cocktails_file_path = 'cocktails.csv'
cocktails_df = pd.read_csv(cocktails_file_path)

# Replace all cells with '-' with blank
cocktails_df.replace('-', None, inplace=True)

# Assuming 'cocktails_df' is predefined with cocktail names
cocktail_ids = {name: i for i, name in enumerate(cocktails_df['Name'].unique())}

# Display the first few rows of the updated dataset
cocktails_df.head()
# Out:
#    Alcohol              Name Category Making Base Wine  Base Wine Amount  \
# 0        5    Tequila Sunset    Short  Blend   Tequila                30
# 1        7           Chi-Chi     Long  Shake     Vodka                30
# 2       10  Sex on the Beach     Long  Build     Vodka                15
# 3       10      Horse’s Neck     Long  Build    Brandy                45
# 4       11         EL Diablo     Long  Build   Tequila                30
#
#                   Liquor Liquor Amount      Juice Juice Amount  ...  \
# 0                   None          None      Lemon           30  ...
# 1                   None          None  Pineapple           80  ...
# 2  Melon_20/Raspberry_10            30  Pineapple           80  ...
# 3                   None          None       None         None  ...
# 4                   None          None       None         None  ...
#
#   Soda Amount        Others Taste     Type of Glass Salty Savory Sour  Bitter  \
# 0        None           Ice  Mild  Champagne Saucer     0     17   83      17
# 1        None  Coconut Milk  Mild   Armagnac Glasss     0     17   67       0
# 2        None          None  Mild          Highball     0      0   83       0
# 3         200   Lemon Piece  Mild     Old Fashioned    17     17   83       0
# 4         250  Orange Piece  Mild          Highball    17      0   50      17
#
#    Sweet  Spicy
# 0     50      0
# 1     50      0
# 2     50      0
# 3     17      0
# 4     50      0
#
# [5 rows x 23 columns]

# %%
import pandas as pd

# Load the CSV file
file_path = 'user_rating_test.csv'
user_data = pd.read_csv(file_path)

# Display the first few rows of the data
print(user_data.head())
# Out:
#   user_id    cocktail_name  user_rating
# 0  Dharti  Tequila Sunrise            1
# 1  Dharti  Tequila Sunrise            1
# 2  Dharti     Vodka Gimlet            2
# 3  Dharti    Black Russian            2
# 4  Dharti        Manhattan            4

# %%
user_data['cocktail_id'] = user_data['cocktail_name'].map(cocktail_ids)
user_data
# Out:
#   user_id    cocktail_name  user_rating  cocktail_id
# 0  Dharti  Tequila Sunrise            1            8
# 1  Dharti  Tequila Sunrise            1            8
# 2  Dharti     Vodka Gimlet            2           34
# 3  Dharti    Black Russian            2           37
# 4  Dharti        Manhattan            4           40
# 5  Dharti           Mojito            4           25
# 6  Dharti          Negroni            5           23
# 7  Dharti    Old Fashioned            5           39
# 8  Dharti      Bloody Mary            5            5

# %%
# Prepare Data Vault Components

# %%
# Extract hubs
users = user_data[['user_id']].drop_duplicates().reset_index(drop=True)
cocktails = user_data[['cocktail_id', 'cocktail_name']].drop_duplicates().reset_index(drop=True)

# Extract links (user-cocktail relationships with ratings)
links = user_data[['user_id', 'cocktail_id', 'user_rating']]

# Assuming user_attributes and cocktail_attributes are not in the CSV, create synthetic ones
num_users = users.shape[0]
num_cocktails = cocktails.shape[0]

user_attributes = pd.DataFrame({
    'user_id': users['user_id'],
    'age': np.random.randint(18, 70, num_users),
    'location': np.random.choice(['Location_A', 'Location_B', 'Location_C'], num_users)
})

cocktail_attributes = pd.DataFrame({
    'cocktail_id': cocktails['cocktail_id'],
    'type': np.random.choice(['Type_A', 'Type_B', 'Type_C'], num_cocktails),
    'alcohol_content': np.random.uniform(5, 40, num_cocktails)
})

# Combine all parts to create a complete dataset
complete_data = links.merge(user_attributes, on='user_id').merge(cocktail_attributes, on='cocktail_id')

# Display the first few rows of the complete dataset
print(complete_data.head())
# Out:
#   user_id  cocktail_id  user_rating  age    location    type  alcohol_content
# 0  Dharti            8            1   57  Location_C  Type_C        31.192504
# 1  Dharti            8            1   57  Location_C  Type_C        31.192504
# 2  Dharti           34            2   57  Location_C  Type_B         9.274512
# 3  Dharti           37            2   57  Location_C  Type_A        39.627484
# 4  Dharti           40            4   57  Location_C  Type_C        30.514687

# %%
# Generate Synthetic Data using SDV

# %%
from sdv.tabular import GaussianCopula

# Train a model using SDV
model = GaussianCopula()
model.fit(complete_data)

# Generate synthetic data
synthetic_data = model.sample(num_rows=10000)  # Generate 10,000 synthetic rows
print(synthetic_data.head())

# Save the synthetic data to a CSV file
synthetic_data.to_csv('synthetic_user_ratings.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sdv.tabular import GaussianCopula
#       3 # Train a model using SDV
#       4 model = GaussianCopula()
#
# ModuleNotFoundError: No module named 'sdv.tabular'

# %%
# conda install -c pytorch -c conda-forge sdv

# %%
from sdv.datasets.demo import download_demo

real_data, metadata = download_demo(
    modality='single_table',
    dataset_name='fake_hotel_guests')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sdv.datasets.demo import download_demo
# ----> 3 real_data, metadata = download_demo(
#       4     modality='single_table',
#       5     dataset_name='fake_hotel_guests')
#
# File ~/anaconda3/lib/python3.11/site-packages/sdv/datasets/demo.py:149, in download_demo(modality, dataset_name, output_folder_name)
#     147 _validate_modalities(modality)
#     148 _validate_output_folder(output_folder_name)
# --> 149 bytes_io = _download(modality, dataset_name)
#     150 in_memory_directory = _extract_data(bytes_io, output_folder_name)
#     151 data = _get_data(modality, output_folder_name, in_memory_directory)
#
# File ~/anaconda3/lib/python3.11/site-packages/sdv/datasets/demo.py:54, in _download(modality, dataset_name)
#      52 LOGGER.info(f'Downloading dataset {dataset_name} from {dataset_url}')
#      53 try:
# ---> 54     file_content = _get_data_from_bucket(object_key)
#      55 except ClientError:
#      56     raise ValueError(
#      57         f"Invalid dataset name '{dataset_name}'. "
#      58         'Make sure you have the correct modality for the dataset name or '
#      59         "use 'get_available_demos' to get a list of demo datasets."
#      60     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sdv/datasets/demo.py:44, in _get_data_from_bucket(object_key)
#      42 def _get_data_from_bucket(object_key):
#      43     session = boto3.Session()
# ---> 44     s3 = session.client('s3', config=Config(signature_version=SIGNATURE_VERSION))
#      45     response = s3.get_object(Bucket=BUCKET, Key=object_key)
#      46     return response['Body'].read()
#
# File ~/anaconda3/lib/python3.11/site-packages/boto3/session.py:299, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     217 def client(
#     218     self,
#     219     service_name,
#    (...)
#     228     config=None,
#     229 ):
#     230     """
#     231     Create a low-level service client by name.
#     232
#    (...)
#     297
#     298     """
# --> 299     return self._session.create_client(
#     300         service_name,
#     301         region_name=region_name,
#     302         api_version=api_version,
#     303         use_ssl=use_ssl,
#     304         verify=verify,
#     305         endpoint_url=endpoint_url,
#     306         aws_access_key_id=aws_access_key_id,
#     307         aws_secret_access_key=aws_secret_access_key,
#     308         aws_session_token=aws_session_token,
#     309         config=config,
#     310     )
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/session.py:997, in Session.create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     980 self._add_configured_endpoint_provider(
#     981     client_name=service_name,
#     982     config_store=config_store,
#     983 )
#     985 client_creator = botocore.client.ClientCreator(
#     986     loader,
#     987     endpoint_resolver,
#    (...)
#     995     user_agent_creator=user_agent_creator,
#     996 )
# --> 997 client = client_creator.create_client(
#     998     service_name=service_name,
#     999     region_name=region_name,
#    1000     is_secure=use_ssl,
#    1001     endpoint_url=endpoint_url,
#    1002     verify=verify,
#    1003     credentials=credentials,
#    1004     scoped_config=self.get_scoped_config(),
#    1005     client_config=config,
#    1006     api_version=api_version,
#    1007     auth_token=auth_token,
#    1008 )
#    1009 monitor = self._get_internal_component('monitor')
#    1010 if monitor is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/client.py:145, in ClientCreator.create_client(self, service_name, region_name, is_secure, endpoint_url, verify, credentials, scoped_config, api_version, client_config, auth_token)
#     138     partition_data = None
#     139     logger.info(
#     140         'No endpoints ruleset found for service %s, falling back to '
#     141         'legacy endpoint routing.',
#     142         service_name,
#     143     )
# --> 145 cls = self._create_client_class(service_name, service_model)
#     146 region_name, client_config = self._normalize_fips_region(
#     147     region_name, client_config
#     148 )
#     149 endpoint_bridge = ClientEndpointBridge(
#     150     self._endpoint_resolver,
#     151     scoped_config,
#    (...)
#     157     ),
#     158 )
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/client.py:198, in ClientCreator._create_client_class(self, service_name, service_model)
#     196 bases = [BaseClient]
#     197 service_id = service_model.service_id.hyphenize()
# --> 198 self._event_emitter.emit(
#     199     'creating-client-class.%s' % service_id,
#     200     class_attributes=class_attributes,
#     201     base_classes=bases,
#     202 )
#     203 class_name = get_service_module_name(service_model)
#     204 cls = type(str(class_name), tuple(bases), class_attributes)
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/boto3/utils.py:65, in lazy_call.<locals>._handler(**kwargs)
#      63 def _handler(**kwargs):
#      64     module, function_name = full_name.rsplit('.', 1)
# ---> 65     module = import_module(module)
#      66     kwargs.update(parent_kwargs)
#      67     return getattr(module, function_name)(**kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/boto3/utils.py:56, in import_module(name)
#      50 def import_module(name):
#      51     """Import module given a name.
#      52
#      53     Does not support relative imports.
#      54
#      55     """
# ---> 56     __import__(name)
#      57     return sys.modules[name]
#
# File ~/anaconda3/lib/python3.11/site-packages/boto3/s3/inject.py:18
#      15 from botocore.exceptions import ClientError
#      17 from boto3 import utils
# ---> 18 from boto3.s3.transfer import (
#      19     ProgressCallbackInvoker,
#      20     S3Transfer,
#      21     TransferConfig,
#      22     create_transfer_manager,
#      23 )
#      26 def inject_s3_transfer_methods(class_attributes, **kwargs):
#      27     utils.inject_attribute(class_attributes, 'upload_file', upload_file)
#
# File ~/anaconda3/lib/python3.11/site-packages/boto3/s3/transfer.py:134
#     130 from botocore.exceptions import ClientError
#     131 from s3transfer.exceptions import (
#     132     RetriesExceededError as S3TransferRetriesExceededError,
#     133 )
# --> 134 from s3transfer.futures import NonThreadedExecutor
#     135 from s3transfer.manager import TransferConfig as S3TransferConfig
#     136 from s3transfer.manager import TransferManager
#
# File ~/anaconda3/lib/python3.11/site-packages/s3transfer/futures.py:22
#      20 from s3transfer.compat import MAXINT
#      21 from s3transfer.exceptions import CancelledError, TransferNotDoneError
# ---> 22 from s3transfer.utils import FunctionContainer, TaskSemaphore
#      24 logger = logging.getLogger(__name__)
#      27 class BaseTransferFuture:
#
# File ~/anaconda3/lib/python3.11/site-packages/s3transfer/utils.py:30
#      24 from botocore.exceptions import (
#      25     IncompleteReadError,
#      26     ReadTimeoutError,
#      27     ResponseStreamingError,
#      28 )
#      29 from botocore.httpchecksum import AwsChunkedWrapper
# ---> 30 from botocore.utils import is_s3express_bucket
#      32 from s3transfer.compat import SOCKET_ERROR, fallocate, rename_file
#      34 MAX_PARTS = 10000
#
# ImportError: cannot import name 'is_s3express_bucket' from 'botocore.utils' (/Users/dhartipatelseagraves/anaconda3/lib/python3.11/site-packages/botocore/utils.py)

# %%
from sdv.lite import SingleTablePreset

synthesizer = SingleTablePreset(metadata, name='FAST_ML')
synthesizer.fit(data=real_data)

# %%
synthetic_data = synthesizer.sample(num_rows=500)

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata)

# %%
Creating report: 100%|██████████| 4/4 [00:00<00:00, 19.30it/s]
Overall Quality Score: 89.12%
Properties:
Column Shapes: 90.27%
Column Pair Trends: 87.97%

# %%
from sdv.evaluation.single_table import get_column_plot

fig = get_column_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_name='amenities_fee',
    metadata=metadata
)
    
fig.show()
